# %%
import numpy as np
import glob
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
mask_files = glob.glob('multi_masks/*.npy')
for mask_file in mask_files:
    multi_mask = np.load(mask_file)
    if len(np.unique(multi_mask)) > 2:
        print(mask_file)
# Out:
# multi_masks/f81ca7ee25e733ff37240c34c8e3044d9937bb0166e315952ebde3f237ecb86f.npy
# multi_masks/ed4b8e0d756836be7acb2e2b7799c473b52424e3092a71d3c6d23558e500dc4c.npy
# multi_masks/6c67b78e8164801059375ed9a607f61e67a7ae347e92e36a7f20514224541d56.npy
# multi_masks/724b6b7044522f6d5ea35b55f8fa71d0a45a28687be2b7cac3149943ab816eec.npy
# multi_masks/d4d6c683f249d82518431603bf0206d05f2114ac871a99ffade0f5f61cf167e1.npy
# multi_masks/3441821ebea04face181c9e2f4d0d09727c764827ac51b9e7fbadbebabeab225.npy
# multi_masks/9bf9f3dcadeb152a9a26b23e2fb199dcf9b2b17660b1646326f5b10cbf51eaee.npy
# multi_masks/615985773f1469fbc00915b3e82d1d4942051c09ddea2667e37ad361ed2e9d59.npy
# multi_masks/28d33efef218392e79e385906deb88055d94b65ad217de78c07e85476f80f45a.npy
# multi_masks/a9d884ba0929dac87c2052ce5b15034163685317d7cff45c40b0f7bd9bd4d9e7.npy
# multi_masks/813f41ef376c3cbcc9d6e2ce6a51c2ee068226d1c1b13404eb238dcfdd447c97.npy
# multi_masks/1b6044e4858a9b7cee9b0028d8e54fbc8fb72e6c4424ab5b9f3859bfc72b33c5.npy
# ...

# %%
multi_mask.shape
# Out:
# (520, 696)

# %%
plt.imshow(multi_mask)

# %%
np.unique(multi_mask)
# Out:
# array([0, 1], dtype=int32)
